# %%
import pandas as pd
import os

# %%
pd.read_csv("../csv/2017/201701_expense_list.csv")

# %%
#지정된 경로에 있는 파일 목록
files = os.listdir("../csv/2017")
files
# Out:
# ['201702_expense_list.csv',
#  '201709_expense_list.csv',
#  '201712_expense_list.csv',
#  '201706_expense_list.csv',
#  '201703_expense_list.csv',
#  '201708_expense_list.csv',
#  '201707_expense_list.csv',
#  '201704_expense_list.csv',
#  '201710_expense_list.csv',
#  '201701_expense_list.csv',
#  '201705_expense_list.csv',
#  '201711_expense_list.csv']

# %% [markdown]
# 1. 파일목록 출력
# 2. 파일 목록을 불러와서 concat() 하나의 데이터 프레임으로 결합

# %%
df_2017 = pd.DataFrame()
path = "../csv/2017/"
for file in files:
    df = pd.read_csv(path+file)
    df_2017 = pd.concat([df_2017, df], axis = 0, ignore_index= True)

# %% [markdown]
# 1. csv/2018에 있는 파일들도 df_2018로 데이터 프레임으로 변환
# 2. total_df만들어서 2017데이터와 2018데이터를 결합

# %%
files = os.listdir("../csv/2018")

df_2018 = pd.DataFrame()

path = "../csv/2018/"

for file in files:
    df = pd.read_csv(path+file)
    df_2018 = pd.concat([df_2018, df], axis=0, ignore_index=True)
df_2018
# Out:
#             nid                                      title  \
# 0      14618781       2018년 1월 서울시본청 기후환경본부 환경정책과 업무추진비 내역
# 1      14618781       2018년 1월 서울시본청 기후환경본부 환경정책과 업무추진비 내역
# 2      14618781       2018년 1월 서울시본청 기후환경본부 환경정책과 업무추진비 내역
# 3      14618781       2018년 1월 서울시본청 기후환경본부 환경정책과 업무추진비 내역
# 4      14618781       2018년 1월 서울시본청 기후환경본부 환경정책과 업무추진비 내역
# ...         ...                                        ...
# 72213  17400394  2018년 12월 서울시본청 행정국 총무과 업무추진비 - 기관운영 시책추진
# 72214  17400394  2018년 12월 서울시본청 행정국 총무과 업무추진비 - 기관운영 시책추진
# 72215  17400394  2018년 12월 서울시본청 행정국 총무과 업무추진비 - 기관운영 시책추진
# 72216  17400394  2018년 12월 서울시본청 행정국 총무과 업무추진비 - 기관운영 시책추진
# 72217  17400394  2018년 12월 서울시본청 행정국 총무과 업무추진비 - 기관운영 시책추진
#
#                                               url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0      http://opengov.seoul.go.kr/public/14618781         서울시본청        기후환경본부
# 1      http://opengov.seoul.go.kr/public/14618781         서울시본청        기후환경본부
# 2      http://opengov.seoul.go.kr/public/14618781         서울시본청        기후환경본부
# 3      http://opengov.seoul.go.kr/public/14618781         서울시본청        기후환경본부
# 4      http://opengov.seoul.go.kr/public/14618781         서울시본청        기후환경본부
# ...                                           ...           ...           ...
# 72213  http://opengov.seoul.go.kr/public/17400394         서울시본청           행정국
# 72214  http://opengov.seoul.go.kr/public/17400394         서울시본청           행정국
# 72215  http://opengov.seoul.go.kr/public/17400394         서울시본청           행정국
# 72216  http://opengov.seoul.go.kr/public/17400394         서울시본청           행정국
# 72217  http://opengov.seoul.go.kr/public/17400394         서울시본청           행정국
#
#       dept_nm_lvl_3 dept_nm_lvl_4 dept_nm_lvl_5  exec_yr  exec_month  \
# 0             환경정책과           NaN           NaN     2018           1
# 1             환경정책과           NaN           NaN     2018           1
# 2             환경정책과           NaN           NaN     2018           1
# 3             환경정책과           NaN           NaN     2018           1
# 4             환경정책과           NaN           NaN     2018           1
# ...             ...           ...           ...      ...         ...
# 72213           총무과           NaN           NaN     2018          12
# 72214           총무과           NaN           NaN     2018          12
# 72215           총무과           NaN           NaN     2018          12
# 72216           총무과           NaN           NaN     2018          12
# 72217           총무과           NaN           NaN     2018          12
#
#        expense_budget  expense_execution      category  dept_nm_full  \
# 0                 NaN                NaN           NaN  기후환경본부 환경정책과
# 1                 NaN                NaN           NaN  기후환경본부 환경정책과
# 2                 NaN                NaN           NaN  기후환경본부 환경정책과
# 3                 NaN                NaN           NaN  기후환경본부 환경정책과
# 4                 NaN                NaN           NaN  기후환경본부 환경정책과
# ...               ...                ...           ...           ...
# 72213             NaN                NaN   시정 관련 간담회 등       행정국 총무과
# 72214             NaN                NaN  현업-우수부서 격려 등       행정국 총무과
# 72215             NaN                NaN   시정 관련 간담회 등       행정국 총무과
# 72216             NaN                NaN   시정 관련 간담회 등       행정국 총무과
# 72217             NaN                NaN   시정 관련 간담회 등       행정국 총무과
#
#                 exec_dt    exec_loc  \
# 0      2018-01-31 20:08    남도한식　고운님
# 1      2018-01-31 13:13  주식회사　동원브이아
# 2      2018-01-30 13:09         복성각
# 3      2018-01-29 13:01          대복
# 4      2018-01-26 20:54        라칸티나
# ...                 ...         ...
# 72213  2018-12-05 09:22   파리크라상／인사동
# 72214  2018-12-04 13:50  （주）미스터피자　청
# 72215  2018-12-04 12:55        안국교자
# 72216  2018-12-01 13:30       달인청국장
# 72217  2018-12-01 08:45      종가집설렁탕
#
#                                           exec_purpose       target_nm  \
# 0      환수위 2018년 본부 현안사업 추진 협력방안 검토 간담회 실시 비용 지출(1.31)   기후환경본부장 외 15명
# 1                 동북아 대기질개선 국제포럼 준비 검토 간담회 비용 지출(1.31)    기후환경본부장 외 6명
# 2                서울연구원 기후에너지센터 협업과제 발굴 간담회 비용 지출(1.30)   기후환경본부장 외 10명
# 3                         환경교육 협치사업 논의 간담회 비용 지출(1.29)    기후환경본부장 외 9명
# 4             미세먼지 비상저감조치 시행 및 개선방안 검토 간담회 비용 지출(1.26)   기후환경본부장 외 15명
# ...                                                ...             ...
# 72213                              시정 주요사업 추진점검 관련 간담회         시장 외 8명
# 72214                노동존중특별시 서울 2018 실행계획 추진관련 노고직원 격려  일자리노동정책관 외 70명
# 72215                                   시정 정책 의견수렴 간담회         시장 외 5명
# 72216                                   시정 정책 지역협력 간담회        시장 외 12명
# 72217                                   시정 정책 지역협력 간담회         시장 외 9명
#
#       payment_method  exec_amount
# 0                 카드       283000
# 1                 카드       128000
# 2                 카드       160000
# 3                 카드       184000
# 4                 카드       326000
# ...              ...          ...
# 72213             카드       147000
# 72214             카드      1228100
# 72215             카드       150000
# 72216             카드       280000
# 72217             카드       180000
#
# [72218 rows x 20 columns]

# %%
## total_df df_2017과 df_2018을 행 추가 단순 결합
total_df = pd.concat([df_2017, df_2018], axis=0, ignore_index=True)

# %%
total_df.tail()
# Out:
#              nid                                      title  \
# 142345  17400394  2018년 12월 서울시본청 행정국 총무과 업무추진비 - 기관운영 시책추진
# 142346  17400394  2018년 12월 서울시본청 행정국 총무과 업무추진비 - 기관운영 시책추진
# 142347  17400394  2018년 12월 서울시본청 행정국 총무과 업무추진비 - 기관운영 시책추진
# 142348  17400394  2018년 12월 서울시본청 행정국 총무과 업무추진비 - 기관운영 시책추진
# 142349  17400394  2018년 12월 서울시본청 행정국 총무과 업무추진비 - 기관운영 시책추진
#
#                                                url dept_nm_lvl_1  \
# 142345  http://opengov.seoul.go.kr/public/17400394         서울시본청
# 142346  http://opengov.seoul.go.kr/public/17400394         서울시본청
# 142347  http://opengov.seoul.go.kr/public/17400394         서울시본청
# 142348  http://opengov.seoul.go.kr/public/17400394         서울시본청
# 142349  http://opengov.seoul.go.kr/public/17400394         서울시본청
#
#        dept_nm_lvl_2 dept_nm_lvl_3 dept_nm_lvl_4 dept_nm_lvl_5  exec_yr
# 6389             운영과 동절기 시설물관리 직원 격려 비용       운영부장외 6명             카드
# 6390  2019년 운영과 주업업무 및 현안업무추진 소통 간담회 비용       운영부장외 8명             카드
# 6391         2019년 전시 및 문화행사 홍보에 관한 간담회      운영부장외 11명             카드
#
#       exec_amount
# 0          143000
# 1           24000
# 2           84000
# 3           78000
# 4          251000
# ...           ...
# 6387        80000
# 6388        78000
# 6389        52000
# 6390       113000
# 6391       120000
#
# [6392 rows x 20 columns]

# %%
pd.read_excel("../csv/2020/202001_expense_list.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     137 try:
# --> 138     module = importlib.import_module(name)
#     139 except ImportError:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:973, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /Users/chulwonchae/UBION/220902/sample3.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/chulwonchae/UBION/220902/sample3.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> pd.read_excel("../csv/2020/202001_expense_list.xlsx")
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/excel/_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/excel/_base.py:1419, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1416 self.engine = engine
#    1417 self.storage_options = storage_options
# -> 1419 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/excel/_openpyxl.py:524, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     509 def __init__(
#     510     self,
#     511     filepath_or_buffer: FilePath | ReadBuffer[bytes],
#     512     storage_options: StorageOptions = None,
#     513 ) -> None:
#     514     """
#     515     Reader using openpyxl engine.
#     516
#    (...)
#     522         passed to fsspec for appropriate URLs (see ``_get_filepath_or_buffer``)
#     523     """
# --> 524     import_optional_dependency("openpyxl")
#     525     super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/compat/_optional.py:141, in import_optional_dependency(name, extra, errors, min_version)
#     139 except ImportError:
#     140     if errors == "raise":
# --> 141         raise ImportError(msg)
#     142     else:
#     143         return None
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
pip  install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 4.8 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel("../csv/2020/202001_expense_list.xlsx", engine="openpyxl")
# Out:
#            nid                                             title  \
# 0     21789676             2020년 1월 사업소 서울식물원 시설운영과 업무추진비 - 부서운영
# 1     21762080   2020년 1월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 부서운영
# 2     21762080   2020년 1월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 부서운영
# 3     21762080   2020년 1월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 부서운영
# 4     21762080   2020년 1월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 부서운영
# ...        ...                                               ...
# 5277  19740729  2020년 1월 서울시본청 시민소통기획관 시민소통담당관 업무추진비 - 기관운영 시책추진
# 5278  19740729  2020년 1월 서울시본청 시민소통기획관 시민소통담당관 업무추진비 - 기관운영 시책추진
# 5279  19740729  2020년 1월 서울시본청 시민소통기획관 시민소통담당관 업무추진비 - 기관운영 시책추진
# 5280  19740729  2020년 1월 서울시본청 시민소통기획관 시민소통담당관 업무추진비 - 기관운영 시책추진
# 5281  19740729  2020년 1월 서울시본청 시민소통기획관 시민소통담당관 업무추진비 - 기관운영 시책추진
#
#                                              url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0     http://opengov.seoul.go.kr/public/21789676           사업소         서울식물원
# 1     http://opengov.seoul.go.kr/public/21762080           사업소       상수도사업본부
# 2     http://opengov.seoul.go.kr/public/21762080           사업소       상수도사업본부
# 3     http://opengov.seoul.go.kr/public/21762080           사업소       상수도사업본부
# 4     http://opengov.seoul.go.kr/public/21762080           사업소       상수도사업본부
# ...                                          ...           ...           ...
# 5277  http://opengov.seoul.go.kr/public/19740729         서울시본청       시민소통기획관
# 5278  http://opengov.seoul.go.kr/public/19740729         서울시본청       시민소통기획관
# 5279  http://opengov.seoul.go.kr/public/19740729         서울시본청       시민소통기획관
# 5280  http://opengov.seoul.go.kr/public/19740729         서울시본청       시민소통기획관
# 5281  http://opengov.seoul.go.kr/public/19740729         서울시본청       시민소통기획관
#
#      dept_nm_lvl_3 dept_nm_lvl_4 dept_nm_lvl_5  exec_yr  exec_month  \
# 0            시설운영과           NaN           NaN     2020           1
# 1          남부수도사업소         행정지원과           NaN     2020           1
# 2          남부수도사업소         행정지원과           NaN     2020           1
# 3          남부수도사업소         행정지원과           NaN     2020           1
# 4          남부수도사업소         행정지원과           NaN     2020           1
# ...            ...           ...           ...      ...         ...
# 5277       시민소통담당관           NaN           NaN     2020           1
# 5278       시민소통담당관           NaN           NaN     2020           1
# 5279       시민소통담당관           NaN           NaN     2020           1
# 5280       시민소통담당관           NaN           NaN     2020           1
# 5281       시민소통담당관           NaN           NaN     2020           1
#
#       expense_budget  expense_execution category       dept_nm_full  \
# 0                NaN                NaN      NaN  푸른도시국 서울식물원 시설운영과
# 1                NaN                NaN      NaN      남부수도사업소 행정지원과
# 2                NaN                NaN      NaN      남부수도사업소 행정지원과
# 3                NaN                NaN      NaN      남부수도사업소 행정지원과
# 4                NaN                NaN      NaN      남부수도사업소 행정지원과
# ...              ...                ...      ...                ...
# 5277             NaN                NaN      NaN            시민소통담당관
# 5278             NaN                NaN      NaN            시민소통담당관
# 5279             NaN                NaN      NaN            시민소통담당관
# 5280             NaN                NaN      NaN            시민소통담당관
# 5281             NaN                NaN      NaN            시민소통담당관
#
#                exec_dt                       exec_loc  \
# 0     2020-01-22 10:25       코코호도마곡나루역점(강서구 마곡중앙5로 6)
# 1     2020-01-29 08:55  ㈜한국문화진흥(강남구 강남대로 636, 두원빌딩2층)
# 2     2020-01-28 12:05         스시사도(영등포구 여의대방로23길 20)
# 3     2020-01-23 11:59           올갱이나라(영등포구 대방천로 234)
# 4     2020-01-23 14:45           두드림유통(동작구 보라매로19길 8)
# ...                ...                            ...
# 5277  2020-01-13 19:57                곰국시집(중구 무교로 24)
# 5278  2020-01-13 13:04                     세림(중구 을지로)
# 5279  2020-01-13 12:20               더미시청점(중구 남대문로9길)
# 5280  2020-01-10 22:20              통인스윗팩토리(종로구 필운대로)
# 5281  2020-01-10 21:05           (주)에프아이티시스템(종로구 누하동)
#
#                           exec_purpose  \
# 0                       부서 전출직원 간담회 비용
# 1                2020년도 1월 생일자 격려상품 구매
# 2      2020년 상반기 학교아리수 음수대 감면 간담회 경비지급
# 3     2020년 설연휴기간 급수대책 및 수질관리 간담회 경비지급
# 4            2020년 민원실 직원 격려 물품구매 경비지급
# ...                                ...
# 5277           박물관도시 서울 추진회의 결과 검토 간담회
# 5278            시정 협력 관련 유관기관 업무협의 간담회
# 5279                  제로페이 추진경과 검토 간담회
# 5280            시정 운영 관련 유관기관 업무협의 간담회
# 5281         시정 소통협력을 위한 유관기관 의견수렴 간담회
#
#                                     target_nm payment_method  exec_amount
# 0                                    이형선 외 3인             카드        30000
# 1                               1월 직원 생일자 12명             카드       216720
# 2     박영준,이상봉,이재욱,이대영,김춘근,김근태,박화준,박병국,조승용,전윤수             카드       124000
# 3                      김지형,신민철,서영식,최신,이혜숙,여종순             카드        48000
# 4                                      해당사항없음             카드        63310
# ...                                       ...            ...          ...
# 5277                             시민소통기획관 외 3명           제로페이        60000
# 5278                             대외협력보좌관 외 2명             카드        51000
# 5279                             시민소통담당관 외 3명           제로페이        40000
# 5280                               정무비서관 외 2명             카드        51000
# 5281                                정무수석 외 6명             카드       162000
#
# [5282 rows x 20 columns]

# %%
## dataframe 정보
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142350 entries, 0 to 142349
# Data columns (total 20 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   nid                142350 non-null  int64
#  1   title              142350 non-null  object
#  2   url                142350 non-null  object
#  3   dept_nm_lvl_1      142350 non-null  object
#  4   dept_nm_lvl_2      142156 non-null  object
#  5   dept_nm_lvl_3      124092 non-null  object
#  6   dept_nm_lvl_4      37693 non-null   object
#  7   dept_nm_lvl_5      6874 non-null    object
#  8   exec_yr            142350 non-null  int64
#  9   exec_month         142350 non-null  int64
#  10  expense_budget     6001 non-null    float64
#  11  expense_execution  5015 non-null    float64
#  12  category           2985 non-null    object
#  13  dept_nm_full       142271 non-null  object
#  14  exec_dt            142350 non-null  object
#  15  exec_loc           140883 non-null  object
#  16  exec_purpose       142328 non-null  object
#  17  target_nm          141594 non-null  object
#  18  payment_method     142147 non-null  object
#  19  exec_amount        142350 non-null  int64
# dtypes: float64(2), int64(4), object(14)
# memory usage: 21.7+ MB

# %% [markdown]
# total_df (2017, 2018 합친 데이터프레임)
#
# 1. 컬럼의 이름 변경 ['nid', '제목', 'url', '부서레벨1', '부서레벨2', '부서레벨3', '부서레벨4', '부서레벨5', '집행연도', '집행일', '예산', '집행', '구분', '부서명', '집행일시', '집행장소', '집행목적', '대상인원', '결제방법', '집행금액']
# 2. 컬럼 삭제 -> 부서레벨3, 부서레벨4, 부서레벨5, 예산, 집행, 구분
# 3. 연도별 집행금액의 합 -> 시각화 (바형 그래프)
# 4. 연도, 월 별 집행금액 합계를 시각화(바형 그래프)

# %%
## 컬럼의 이름을 변경
total_df.columns = ['nid', '제목', 'url', '부서레벨1', '부서레벨2', '부서레벨3', '부서레벨4', '부서레벨5', '집행연도', '집행일', '예산', '집행', '구분', '부서명', '집행일시', '집행장소', '집행목적', '대상인원', '결제방법', '집행금액']

# %%
total_df.drop(["부서레벨3", "부서레벨4", "부서레벨5", "예산", "집행", "구분"], axis=1, inplace=True)

# %%
total_df.head(1)
# Out:
#         nid                                    제목  \
# 0  11527154  2017년 2월 시의회사무처 보건복지전문위원실 업무추진비 집행내역
#
#                                           url  부서레벨1      부서레벨2  집행연도  집행일  \
# 0  http://opengov.seoul.go.kr/public/11527154  의회사무처  보건복지전문위원실  2017    2
#
#                 부서명              집행일시                 집행장소  \
# 0  시의회사무처 보건복지전문위원실  2017-02-23 12:54  （주）스타벅스커피코 (중구 소공로)
#
#                     집행목적         대상인원 결제방법   집행금액
# 0  제272회 임시회 현장방문 논의 간담회  수석전문위원 외 5명   카드  30000

# %%
## 집행 연도를 기준으로 그룹화 집행금액의 합계를 출력
month_total = total_df.groupby("집행연도").sum()["집행금액"]
month_total
# Out:
# 집행연도
# 2017    9076941387
# 2018    9937556542
# Name: 집행금액, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
## 바형 그래프 
## x축 -> index
## y축 -> 집행금액의 합계
x = month_total.index
y = month_total

plt.bar(x, y)
plt.show()

# %%
## pivot_table()의 형태로 변경 시각화
month_total = pd.pivot_table(total_df, index=["집행연도"], values=["집행금액"], aggfunc='sum')
month_total
# Out:
#             집행금액
# 집행연도
# 2017  9076941387
# 2018  9937556542

# %%
matplotlib.rcParams["font.family"] = "Malgun Gothic"
matplotlib.rcParams["axes.unicode_minus"] = False

(month_total).plot.barh()
# Out:
# <AxesSubplot:ylabel='집행연도'>
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
## 연도별 월별
month_total = total_df.groupby(["집행연도", "집행일"]).sum()["집행금액"]
month_total
# Out:
# 집행연도  집행일
# 2017  1       710368860
#       2       712679864
#       3       737250454
#       4       635265805
#       5       647582378
#       6       758257342
#       7       701604626
#       8       661174850
#       9       806170700
#       10      637219943
#       11      843619171
#       12     1225747394
# 2018  1       735587570
#       2       769360005
#       3       761059010
#       4       703781418
#       5       669044701
#       6       690652154
#       7       788926477
#       8       730290532
#       9       769404957
#       10      827022975
#       11      960310221
#       12     1532116522
# Name: 집행금액, dtype: int64

# %%
month_total.plot.bar()
# Out:
# <AxesSubplot:xlabel='집행연도,집행일'>
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
pivot_month = pd.pivot_table(total_df, index=["집행일"], columns=["집행연도"], 
values=["집행금액"], aggfunc='sum')
pivot_month
# Out:
#             집행금액
# 집행연도        2017        2018
# 집행일
# 1      710368860   735587570
# 2      712679864   769360005
# 3      737250454   761059010
# 4      635265805   703781418
# 5      647582378   669044701
# 6      758257342   690652154
# 7      701604626   788926477
# 8      661174850   730290532
# 9      806170700   769404957
# 10     637219943   827022975
# 11     843619171   960310221
# 12    1225747394  1532116522

# %%
pivot_month.plot.bar()
# Out:
# <AxesSubplot:xlabel='집행일'>
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 집행연도와 부서레벨1 별 집행 금액의 평균이 어떠한가 그래프로 표시

# %%
dep_total = pd.pivot_table(total_df, index=["부서레벨1"], columns=["집행연도"], 
values=["집행금액"], aggfunc='mean')
dep_total
# Out:
#                       집행금액
# 집행연도                  2017           2018
# 부서레벨1
# 사업소          120432.199322  124290.371469
# 서울시본청        119812.339642  130286.126921
# 소방재난본부(소방서)  215503.983578  226244.982045
# 의회사무처        101912.491923  104341.926548

# %%
dep_total.plot.barh()
# Out:
# <AxesSubplot:ylabel='부서레벨1'>
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 48376 (\N{HANGUL SYLLABLE BON}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 48169 (\N{HANGUL SYLLABLE BANG}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51116 (\N{HANGUL SYLLABLE JAE}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 45212 (\N{HANGUL SYLLABLE NAN}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 54924 (\N{HANGUL SYLLABLE HOE}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 52376 (\N{HANGUL SYLLABLE CEO}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 48296 (\N{HANGUL SYLLABLE BEL}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from current font.
#   func(*args, **kwargs)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48376 (\N{HANGUL SYLLABLE BON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48169 (\N{HANGUL SYLLABLE BANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51116 (\N{HANGUL SYLLABLE JAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45212 (\N{HANGUL SYLLABLE NAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54924 (\N{HANGUL SYLLABLE HOE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52376 (\N{HANGUL SYLLABLE CEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48296 (\N{HANGUL SYLLABLE BEL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chulwonchae/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50529 (\N{HANGUL SYLLABLE AEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
total_df.sort_values("집행일시")
# Out:
#              nid                                            제목  \
# 53360   11019667      2017년 1월 시의회사무처 도시안전건설전문위원실 업무추진비 집행내역
# 63216   12250365                                 5월 업무추진비 사용내역
# 63217   12250365                                 5월 업무추진비 사용내역
# 63218   12250365                                 5월 업무추진비 사용내역
# 18803   12650218                2017년 6월 서울시본청_서울특별시장_업무추진비 내역
# ...          ...                                           ...
# 136599  16919933  2018년 12월 사업소_상수도사업본부_북부수도사업소_급수운영과 업무추진비 내역
# 138946  16950392  2018년 12월 사업소_상수도사업본부_중부수도사업소_행정지원과 업무추진비 내역
# 138941  16950392  2018년 12월 사업소_상수도사업본부_중부수도사업소_행정지원과 업무추진비 내역
# 136598  16919933  2018년 12월 사업소_상수도사업본부_북부수도사업소_급수운영과 업무추진비 내역
